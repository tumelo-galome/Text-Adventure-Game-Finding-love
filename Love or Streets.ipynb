# %%
"""
@author: tumelo.seemule

DocString:
    
    1) Intro:
    This is an 'interactive' text game that is designed to take the user on a little adventure
    the user tries to find love. It requires the user to try reach a favourable outcome depending on the choices 
    they make. If they win, they find love, if not they belong to the streets and dont find love.
    
    Round one: Date 1
    Round two: Waking up in bed
    Round three: Date 2
    
    Ive decided to name this game Love & Streets.

    B) Known Bugs and/or Errors:
    Country input may not work/be incorrect.
    Line 268 will not print slow and also be an input
    Sometimes it prints out the outputs
    
"""

# Importing packages
import random
import time
import webbrowser
import sys
from sys import exit

# Starting point of game        
def intro():
    print_slow("""You are about to either find love or belong to the streets: Are you ready?
Player discretion is advised.\n\t
    """)
    intro_two()

#Game Fail number 1
def gamefail():

    print("""\n .----------------. .----------------. .----------------. .----------------. 
| .--------------. | .--------------. | .--------------. | .--------------. |
| |    ______    | | |      __      | | | ____    ____ | | |  _________   | |
| |  .' ___  |   | | |     /  \     | | ||_   \  /   _|| | | |_   ___  |  | |
| | / .'   \_|   | | |    / /\ \    | | |  |   \/   |  | | |   | |_  \_|  | |
| | | |    ____  | | |   / ____ \   | | |  | |\  /| |  | | |   |  _|  _   | |
| | \ `.___]  _| | | | _/ /    \ \_ | | | _| |_\/_| |_ | | |  _| |___/ |  | |
| |  `._____.'   | | ||____|  |____|| | ||_____||_____|| | | |_________|  | |
| |              | | |              | | |              | | |              | |
| '--------------' | '--------------' | '--------------' | '--------------' |
 '----------------' '----------------' '----------------' '----------------' 
 .----------------. .----------------. .----------------. .----------------. 
| .--------------. | .--------------. | .--------------. | .--------------. |
| |     ____     | | | ____   ____  | | |  _________   | | |  _______     | |
| |   .'    `.   | | ||_  _| |_  _| | | | |_   ___  |  | | | |_   __ \    | |
| |  /  .--.  \  | | |  \ \   / /   | | |   | |_  \_|  | | |   | |__) |   | |
| |  | |    | |  | | |   \ \ / /    | | |   |  _|  _   | | |   |  __ /    | |
| |  \  `--'  /  | | |    \ ' /     | | |  _| |___/ |  | | |  _| |  \ \_  | |
| |   `.____.'   | | |     \_/      | | | |_________|  | | | |____| |___| | |
| |              | | |              | | |              | | |              | |
| '--------------' | '--------------' | '--------------' | '--------------' |
 '----------------' '----------------' '----------------' '----------------' \n""")
    game_looser=input(prompt="""Do you want to replay? Y/N\n""").lower()
    if game_looser == 'y' or game_looser == 'yes':
        intro()
    elif game_looser == 'n' or game_looser =='no':
        exit(0)
    
# Game Success
def gamewin():
    print("""\n .----------------. .----------------. .-----------------..-----------------..----------------. .----------------.                    
| .--------------. | .--------------. | .--------------. | .--------------. | .--------------. | .--------------. |                   
| | _____  _____ | | |     _____    | | | ____  _____  | | | ____  _____  | | |  _________   | | |  _______     | |                   
| ||_   _||_   _|| | |    |_   _|   | | ||_   \|_   _| | | ||_   \|_   _| | | | |_   ___  |  | | | |_   __ \    | |                   
| |  | | /\ | |  | | |      | |     | | |  |   \ | |   | | |  |   \ | |   | | |   | |_  \_|  | | |   | |__) |   | |                   
| |  | |/  \| |  | | |      | |     | | |  | |\ \| |   | | |  | |\ \| |   | | |   |  _|  _   | | |   |  __ /    | |                   
| |  |   /\   |  | | |     _| |_    | | | _| |_\   |_  | | | _| |_\   |_  | | |  _| |___/ |  | | |  _| |  \ \_  | |                   
| |  |__/  \__|  | | |    |_____|   | | ||_____|\____| | | ||_____|\____| | | | |_________|  | | | |____| |___| | |                   
| |              | | |              | | |              | | |              | | |              | | |              | |                   
| '--------------' | '--------------' | '--------------' | '--------------' | '--------------' | '--------------' |                   
 '----------------' '----------------' '----------------' '----------------' '----------------' '----------------'                    
    \n""")
    
# Prompting for user input
    game_winner=input(prompt="""Do you want to replay? Y/N\n""").lower()
    if game_winner == 'y' or game_winner== 'yes':
        intro()
    elif game_winner == 'n' or game_winner =='no':
        exit(0) 

# Creating loop for if date is unattractive.
def lame_date():
    print("Well damn! How are you not attracted to your crush?") 
    
    lame_date=input(prompt="""Do you want to replay? Y/N\n""").lower()
    if lame_date == 'y' or lame_date== 'yes':
        intro()
    elif lame_date == 'n' or lame_date =='no':
        exit(0)

# Timed opening sequence for variation in game play.
def print_slow(str): 
    for letter in str:
        sys.stdout.write(letter)
        sys.stdout.flush()
        time.sleep(0.03)
    
# Starting point for game.
def intro_two():
    input(prompt = "Press Enter to proceed.\n")
    
# Making user inputs global
    global dream_date
    global your_name
    
    # Prompts for user inputs for variables.
    dream_date = input(prompt ="Enter the name of someone you would love to go on a date with:\n").title()
    restaurant_1 = input(prompt ="Enter name of favorite restaurant:\n").title()
    dating_app = input(prompt ="Enter a dating app you use or have used:\n""").title()

    # Print statement including user input.
    print_slow(f"""You met {dream_date} on {dating_app} and this is the first date you have been on since your breakup.\n
(We love to see you healing)
{dream_date} walks over to you in {restaurant_1} after being 2 minutes late!
{dream_date}: Hi there...so sorry I am late.
What's your name again?\n\n""")

    # Prompts for user inputs for variables.
    your_name = input(prompt = "Please type your name:\n").title()

    # Print statement including variable inputs.
    print_slow(f"{dream_date}: Hmmmm...  {your_name} ???\nYou are the most gorgeous {your_name} I have met!\nWhere are you from?\n")
    country_name = input(prompt = "Please input the country you are from:\n").title() 
    print_slow(f"I have actually been to {country_name} and I loved my time there. Maybe next time I can experience it with you...\n\n") 

    # calling udf
    choice()

def choice():
    print_slow(f"""{dream_date}: What exactly are you looking for? Maybe we could skip the dinner and get right to it.\n""")
    #prompting user input
    seeking = input(prompt = """Please choose the relevent number:\n1. Friends\n2. Entanglement\n3. Love\n""").lower()
    
    #list with celebrity duos to be randomly selected from
    lst = ['Zac and Cody','Jada Pinkett Smith and Queen Latifah','Nicole Kidman and Naomi Watts','Jayz and Becky','Will and Jada Smith','Aliyah and Jay-Z','Nelson and Winnie Mandela','Barack and Michelle Obama','Beyonce and Jay-z']
    rand1 =  random.choice(lst[0:2])
    rand2 =  random.choice(lst[3:5])
    rand3 =  random.choice(lst[6:8]) 

    if seeking == '1' or seeking == 'friends' or seeking == 'one' :
            print_slow(f"{dream_date}: Well everything must begin with a friendship right. We could be the next {rand1}.\n I love making new friends.\nPotentially with benefits!!!\n")

    elif seeking == '2' or seeking == 'entanglement' or seeking == 'two':
            print_slow(f"{dream_date}: I am glad! We can be like the next {rand2} .\nI hope you do not get too attached though.\nI tend to be addictive\n")

    elif seeking == '3' or seeking == 'three' or seeking == 'love':
            print_slow(f"{dream_date}: I am glad we are on the same page! I am trying to become the next {rand3}.\n Maybe you are the better half I need.\nI am excited to get with you...\nI mean excited to get to know you...\n")


    # Loop to prompt player to chose an input       
    else:
        print("""What you think this is? You better make up your mind before you end up going home alone. Try again please\n""")
        choice()            
    # Game spacer
    input(prompt = """Press Enter to proceed.\n""")
    attraction_2()

def sprint (str):
    for c in str + '\n':
        sys.stdout.write(c)
        sys.stdout.flush()
        time.sleep(3./90)
    
    #defining how attacted user is to their dream_date
def attraction_2():
    print_slow(f"{dream_date} perks up and seems to be craving you a bit more than in the begining. Your response got {dream_date} excited!\n{dream_date} looks you in the eyes and asks:\n")
    attraction_1= input(prompt ="""Do you find me sexy? Y/N\n""").lower()

    if (attraction_1 == 'y' or attraction_1 == 'yes'):
        print_slow(f"{dream_date}: Damn! I think you look delicious as well.\nI mean sexy!\nOnce we are done here my house is always open to explore eachother.") 
    # If a player decides they are not attracted to their date they are looped to option to restart.
    elif (attraction_1 == 'n' or attraction_1 == 'no'): 
        print_slow(f"{dream_date}: WELL DAMN! WHAT TF ARE YOU DOING HERE ??? You look like you were run over by a truck!!!\nWE BOTH COULD HAVE JUST STAYED HOME. I am leaving your lame ass for the STREETS. hahahaha\n")
    # Loop with  to the begining and give player the option to go on a date with someone they find attractive. 
        lame_date()
    
    else:
        print(f"No actually what do you think?\nPlease try answering that again.\n")
        attraction_2() 

    # Game Spacer
    input(prompt ="Press Enter to proceed.\n")  

    # The sprint speeds up the storyline so 
    sprint(f"""You continue to get to have an amazing conversation.\nThe waiter brings the wine.\nWaiter: What are you celebrating? CHACHACHA.
You both look at eachother because this just got awkward. And the CHACHACHA is ooweird.
{dream_date}: Well, I guess we are celebrating our first date.\nWaiter: CHACHACHA! How exciting. I love first dates. Next thing you know you will be back here in a year celebrating your engagment!\n
You both just laugh as she drags the joke...and you actually ponder for a second, and think that would be so amazing if it did happen. Could she be manifesting this upon your life?m\n""") 

    print_slow(f"{dream_date}: Well {your_name} it's almost 12...I remember you said you need to be home before midnight.\nI should probably take you home, before you turn into a pumpkin.\nUnless, you want to come to my place and just hang out?\n")

    messy_2()
  
    #Calling UDF
def messy_2():
    messy_1 = input(prompt =f"Do you want to go to {dream_date}'s house? Y/N\n").lower() 
    
    if messy_1 == 'y' or messy_1 == 'yes':
        print_slow(f"{dream_date}: We can get up to some messy, dodgy shit, naughty stuff if you like.\nYou definetly belong to the STREETS! You are not meant to go home together on the first date. Soo judging you!\n")
        gamefail()

    elif messy_1 == 'n' or messy_1== 'no':
        print_slow(f"{dream_date}: That's alright baby. We can enjoy a nice evening out and I can show you the city. I am in no rush.\n")
        count()
    else:
        print_slow("Make up your mind we don't have all night. Try again.")
        messy_2()

# While Loop for clapping and teleport on the count of 3
def count():
    print_slow(f"You are now ready to go home and {dream_date} decides to take you home. However, {dream_date} drives like trash and very slow.\nIt is time to clap your hands three times and be teleported to bed!\n\n")
    count = 3
    while count > 1 :
        print(count,"\n*CLAP*\n")
        count = count - 1
        #Game Spacer
        input ("Press Enter to Proceed.\n")

    if count == 1 :
        print(f"BEEP! BEEP!.\n*You reachout to snooze your alarm*") 
        time.sleep(2)

    print_slow(f"You wake up in your bed...HUNGOVER AF! You think to yourself,'Even if we don't see eachother again. I had an amazing night.'\n")
    text_2()
    
# User input for a decision that has the same outcome regardless of choice
def text_2():
    text_1 = input(prompt = f"Do you want to text {dream_date}? Y/N \n").lower()

    if  text_1 == 'y' or text_1 == 'yes' : 
        print_slow(f"You text {dream_date}: Goodmorning! I hope you slept well. I had an amazing night!\n")
        
    elif text_1 == 'n' or text_1 == 'no' :
        print_slow(f"Your phone begins to buzz and it's a text from {dream_date}.\n{dream_date}: I had an amazing night! Never felt so alive. I would love to take you out on a coffee date on Wednesday.\n")
        
    else: 
        print(f"Stop acting childish.\nMake up your mind, are you texting or what?\nPlease try again.\n") 
        text_2()

            print_slow(f"\n\n*Your phone goes off.*\n\n{dream_date}: Here are the details for our Wednesday date!!I will see you on Wednesday!\n{dream_date}: I will be thinking about you until then.\n\n")

# Delay the speed at which the next text prints out
    time.sleep(2)

    print_slow(f"Suddenly it is Wednesday and you are on your way to meet {dream_date}.\nYou have been thinking about this day all week!\n")
# Calling UDF
    date_3()
    
#Defining decision to go on date or not
def date_3():
    date_2 = input(prompt = f"Are you going to meet {dream_date}? Come on don't flake on another one.Y/N\n").lower()
    
    if date_2 == 'y' or date_2 == 'yes' : 
        date = input(prompt = f"""Thats the spirit! You put on a cute outfit. Your best cologne and twerk in the mirror as you leave the house to go on your date.\n  
Damn you look good! You find {dream_date} standing outside Tatte.\nYou have been waiting all week for this moment.\n
Are you excited?Y/N\n""").lower()
                     
        if date == 'y' or date == 'yes':
            print_slow(f"""\nOffcourse you are! {dream_date} is walking perfection!\n""")
            amazing_date()
            
        elif date == 'n' or date == 'no':
            print_slow(f"""Yea no I feel that too! {dream_date} is kind of a loser!
Turn around and run in the opposite direction!The STREETS are calling your name!\n""")
            gamefail()
            
        else:
            print(f"""It seems youve made a mistake, must be the nerves.\nPlease try again.\n""")
            date_3()
               
    elif date_2 == 'n' or date_2 == 'no' :
        print_slow(f"Your phone begins to buzz and it's a text from {dream_date}.\n{dream_date}: Sorry I cant make it! I am not really into you as much. ENJOY THE STREETS!\n")
        gamefail()
        
    else: 
        print(f"Stop acting childish.\nMake up your mind, are you going or not?\nPlease try again.\n") 
        date_3()
        
# Defining stage 3 and final decision   
def amazing_date():
    print_slow(f"""\nYet another amazing date! You walked hand in hand, got some ice cream after an amazing dinner.\nNot forgeting the amazing kiss you got from {dream_date}, this all feels so surreal!\n{dream_date}: I have had an amazing night. Do you want to come over and continue this at my place?\n""")

    messy_1 = input(prompt =f"Do you want to go to {dream_date}'s house? Y/N\n").lower() 

    if   messy_1 == 'y' or messy_1 == 'yes':
        print_slow(f"{dream_date}:Nice! I was hoping you would say that!\nYou definetly belong to the STREETS! You are not meant to go home with anyone until the third date. Soo judging you!\n")
        gamefail()

    elif  messy_1 == 'n' or messy_1== 'no':
        print_slow(f"{dream_date}:Wow! I really LOVE that you reject my invitation so much and I think I LOVE you and want to spent the rest of my life with you!\n")
        gamewin()
    else:
        print("Make up your mind we don't have all night. Try again.")
        amazing_date()       
    
# calling function to start the game
intro()

###############################################################################
#Game Over
# Out:
# You are about to either find love or belong to the streets: Are you ready?
# Player discretion is advised.
#
#     Press Enter to proceed.
#
# Enter the name of someone you would love to go on a date with:
# Tumelo
# Enter name of favorite restaurant:
# jfnj
# Enter a dating app you use or have used:
# jfjf
# You met Tumelo on Jfjf and this is the first date you have been on since your breakup.
#
# (We love to see you healing)
# Tumelo walks over to you in Jfnj after being 2 minutes late!
# Tumelo: Hi there...so sorry I am late.
# What's your name again?
#
# Please type your name:
# ghhjfgj
# Tumelo: Hmmmm...  Ghhjfgj ???
# You are the most gorgeous Ghhjfgj I have met!
# Where are you from?
# Please input the country you are from:
# ckhjkh
# I have actually been to Ckhjkh and I loved my time there. Maybe next time I can experience it with you...
#
# Tumelo: What exactly are you looking for? Maybe we could skip the dinner and get right to it.
# Please choose the relevent number:
# ...
